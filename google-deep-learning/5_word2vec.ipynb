# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))

print(words[:10])
# Out:
# Data size 17005207
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.590879
# Nearest to world: swordsmen, sites, remey, freda, constructing, procellariiformes, remus, inv,
# Nearest to these: resin, egalitarian, verhofstadt, hypatia, salon, sidemen, aquilegia, corvettes,
# Nearest to be: favourite, convoked, rafik, stamp, sherbrooke, cooperated, papandreou, gallatin,
# Nearest to an: teenager, enthalpy, severly, taker, warbird, played, deathbed, virgo,
# Nearest to would: stoppage, tente, extremist, legionnaires, bowler, merriam, purposefully, shuffle,
# Nearest to many: daniell, inmate, success, daunting, uploaded, salicylic, fictions, pmrc,
# Nearest to which: cw, habitable, hypoxic, jumbled, contracts, ralf, naiste, gimmick,
# Nearest to and: invented, ecclesia, macroeconomics, archibald, hyperbola, mama, virology, perennials,
# Nearest to first: dostum, anu, guerre, dijon, allies, oriole, cesare, charted,
# Nearest to their: bam, splines, crunch, dramatized, lapis, expectation, interdependence, capsule,
# Nearest to known: suing, hymns, bouncer, technicality, moc, kiss, costs, lowball,
# Nearest to two: thelma, graphically, theravada, derg, instructional, foreshadowing, cartridges, counterfeit,
# Nearest to six: cuon, eldridge, civilisations, pickens, ddc, bre, intimidating, zimri,
# Nearest to seven: gustavo, guild, kuhn, hamdi, cossiga, amillennialism, decorator, planina,
# Nearest to has: assignments, spaced, aldebaran, behistun, haiku, financially, barbarism, depositing,
# Nearest to new: pol, groves, jerky, candide, modify, auxiliaries, enhance, enforcement,
# Average loss at step 2000: 4.371259
# Average loss at step 4000: 3.864465
# Average loss at step 6000: 3.787842
# Average loss at step 8000: 3.688526
# Average loss at step 10000: 3.613747
# Nearest to world: sites, ipv, remus, constructing, remey, fixtures, masculism, procellariiformes,
# Nearest to these: egalitarian, many, codebreaking, novelette, thorny, resin, corvettes, swarm,
# Nearest to be: have, rafik, favourite, sherbrooke, tycho, been, multivibrator, by,
# Nearest to an: the, collides, lessen, complemented, nahum, niches, tofu, boarded,
# Nearest to would: can, will, filking, could, tied, might, confocal, lakoff,
# Nearest to many: some, fictions, daniell, these, elisabetta, airstrips, copa, inmate,
# Nearest to which: also, it, habitable, that, this, hawker, don, surnames,
# Nearest to and: or, but, who, re, of, s, in, herbrand,
# Nearest to first: nitrogenous, dostum, seldom, whewell, venues, cuboctahedron, mazda, durand,
# Nearest to their: his, the, heapsort, crowe, respective, them, expectation, airstrips,
# Nearest to known: emeralds, moc, suing, weaver, intending, lowball, heroes, cavities,
# Nearest to two: three, five, four, eight, nine, seven, six, one,
# Nearest to six: eight, five, seven, four, nine, three, zero, two,
# Nearest to seven: six, eight, four, five, three, nine, zero, two,
# Nearest to has: had, was, is, sandalwood, have, fiberglass, costanza, penguin,
# Nearest to new: enforcement, modify, eventually, shag, enhance, baraka, jerky, groves,
# Average loss at step 12000: 3.612278
# Average loss at step 14000: 3.572261
# Average loss at step 16000: 3.409981
# Average loss at step 18000: 3.451681
# Average loss at step 20000: 3.545453
# Nearest to world: sites, ipv, nonnegative, remus, constructing, u, remey, hands,
# Nearest to these: many, some, which, such, elements, they, egalitarian, other,
# Nearest to be: have, been, by, is, were, rafik, was, sherbrooke,
# Nearest to an: collides, smoothing, the, tofu, warbird, lessen, transcends, niches,
# Nearest to would: can, will, could, might, should, may, did, to,
# Nearest to many: some, several, these, other, fictions, morocco, synth, all,
# Nearest to which: this, also, that, it, these, who, there, semblance,
# Nearest to and: or, but, which, jewel, herbrand, microseconds, in, at,
# Nearest to first: cuboctahedron, heartbeat, whewell, mazda, dostum, ruining, nitrogenous, second,
# Nearest to their: his, its, the, her, them, rtp, some, crowe,
# Nearest to known: used, emeralds, lowball, suing, intending, moc, heroes, far,
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Nearest to six: seven, eight, five, three, nine, four, zero, two,
# Nearest to seven: eight, six, five, three, nine, four, zero, two,
# Nearest to has: had, is, was, have, sandalwood, costanza, fiberglass, does,
# Nearest to new: enforcement, modify, alec, baraka, shrublands, expatriates, shag, geniuses,
# Average loss at step 22000: 3.503273
# Average loss at step 24000: 3.486767
# Average loss at step 26000: 3.484887
# Average loss at step 28000: 3.479453
# Average loss at step 30000: 3.502602
# Nearest to world: ipv, sites, nonnegative, artillery, u, hands, remus, masculism,
# Nearest to these: some, many, their, such, they, which, elements, all,
# Nearest to be: have, been, is, multivibrator, feud, lynn, was, jaguars,
# Nearest to an: prohibiting, lessen, smoothing, promptly, boarded, niches, tofu, mw,
# Nearest to would: will, can, could, may, should, might, must, did,
# Nearest to many: some, several, these, most, afrikaans, fictions, diagnoses, morocco,
# Nearest to which: this, that, also, who, these, but, it, what,
# Nearest to and: or, but, who, in, of, however, streets, gah,
# Nearest to first: second, last, ruining, cuboctahedron, third, booked, during, dhahran,
# Nearest to their: his, its, the, her, these, some, rtp, many,
# Nearest to known: used, well, such, described, emeralds, intending, regarded, far,
# Nearest to two: three, four, five, one, seven, eight, six, zero,
# Nearest to six: four, five, eight, seven, nine, three, two, zero,
# Nearest to seven: eight, five, nine, four, six, three, two, zero,
# Nearest to has: had, have, is, was, symphonic, sandalwood, antecedents, libri,
# Nearest to new: enforcement, modify, throughout, hotel, savonarola, shrublands, kidnappings, baraka,
# Average loss at step 32000: 3.501176
# Average loss at step 34000: 3.494572
# Average loss at step 36000: 3.454620
# Average loss at step 38000: 3.304084
# Average loss at step 40000: 3.432443
# Nearest to world: u, nonnegative, ipv, masculism, hands, bjelke, vicious, cerium,
# Nearest to these: many, some, several, such, which, various, their, they,
# Nearest to be: been, have, rafik, being, is, are, was, were,
# Nearest to an: smoothing, promptly, lessen, collides, writs, mw, warbird, niches,
# Nearest to would: will, could, can, may, should, might, must, did,
# Nearest to many: some, several, these, fictions, most, their, diagnoses, such,
# Nearest to which: that, this, also, who, these, but, there, it,
# Nearest to and: or, but, glossy, however, in, although, like, when,
# Nearest to first: last, second, next, ruining, fourth, milestones, final, harmed,
# Nearest to their: its, his, her, the, these, some, many, our,
# Nearest to known: used, such, well, described, defined, regarded, considered, possible,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to six: seven, four, eight, five, three, nine, two, one,
# Nearest to seven: six, five, eight, nine, four, three, zero, one,
# Nearest to has: had, have, was, is, libri, antecedents, since, fiberglass,
# Nearest to new: enforcement, tripod, collegiate, kidnappings, alec, stricture, manichaeism, induced,
# Average loss at step 42000: 3.434124
# Average loss at step 44000: 3.454450
# Average loss at step 46000: 3.453352
# Average loss at step 48000: 3.354719
# Average loss at step 50000: 3.382300
# Nearest to world: ipv, u, fantastical, hands, nonnegative, bjelke, masculism, civil,
# Nearest to these: many, some, both, several, various, their, those, such,
# Nearest to be: have, been, being, was, rafik, become, is, were,
# Nearest to an: promptly, lessen, smoothing, niches, dial, complemented, surveillance, collides,
# Nearest to would: will, could, can, should, may, might, must, did,
# Nearest to many: some, several, these, various, both, fictions, numerous, most,
# Nearest to which: that, this, also, who, what, usually, these, often,
# Nearest to and: or, but, while, forgery, s, including, jpeg, of,
# Nearest to first: second, last, next, fourth, final, third, nitrogenous, superb,
# Nearest to their: its, his, her, the, these, our, some, your,
# Nearest to known: used, defined, such, regarded, described, possible, well, part,
# Nearest to two: three, six, four, five, seven, eight, one, zero,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Nearest to seven: six, eight, nine, four, five, three, zero, two,
# Nearest to has: had, have, was, is, having, since, garland, does,
# Nearest to new: stricture, baroque, enforcement, final, manichaeism, icftu, affectionately, megaliths,
# Average loss at step 52000: 3.435952
# Average loss at step 54000: 3.427188
# Average loss at step 56000: 3.438601
# Average loss at step 58000: 3.397575
# Average loss at step 60000: 3.388822
# Nearest to world: ipv, civil, emmer, masculism, u, fantastical, sun, hands,
# Nearest to these: many, some, several, both, those, various, such, they,
# Nearest to be: been, have, rafik, is, wane, become, being, are,
# Nearest to an: promptly, niches, smoothing, lessen, collides, cryptids, dial, amphitheatre,
# Nearest to would: could, will, can, should, may, might, must, did,
# Nearest to many: some, several, these, various, both, most, all, such,
# Nearest to which: that, this, what, who, usually, these, it, typically,
# Nearest to and: or, but, although, including, oligarchic, plots, for, while,
# Nearest to first: last, second, next, fourth, final, third, ruining, clicked,
# Nearest to their: its, his, her, the, our, several, some, these,
# Nearest to known: used, such, defined, regarded, possible, described, well, considered,
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Nearest to six: eight, four, five, seven, nine, three, zero, two,
# Nearest to seven: six, eight, four, nine, five, three, zero, one,
# Nearest to has: had, have, having, was, is, microstate, does, garland,
# Nearest to new: tripod, stricture, final, enforcement, manichaeism, shrublands, lebanon, alves,
# Average loss at step 62000: 3.244534
# Average loss at step 64000: 3.253058
# Average loss at step 66000: 3.404091
# Average loss at step 68000: 3.394881
# Average loss at step 70000: 3.362553
# Nearest to world: u, ipv, civil, whodunit, pianists, masculism, fantastical, emmer,
# Nearest to these: such, many, some, several, those, various, which, their,
# Nearest to be: been, is, were, become, being, rafik, have, are,
# Nearest to an: promptly, enthalpy, smoothing, dial, niches, prohibiting, transcends, complemented,
# Nearest to would: could, will, may, can, should, might, must, cannot,
# Nearest to many: some, several, these, various, such, numerous, both, most,
# Nearest to which: that, this, also, usually, who, but, these, what,
# Nearest to and: or, but, while, which, however, although, trist, coincidentally,
# Nearest to first: second, last, next, final, fourth, third, ruining, irene,
# Nearest to their: its, his, her, the, our, your, these, whose,
# Nearest to known: used, defined, regarded, described, well, possible, considered, such,
# Nearest to two: three, four, six, one, seven, five, eight, zero,
# Nearest to six: eight, seven, four, five, three, nine, two, zero,
# Nearest to seven: six, eight, four, five, nine, three, zero, one,
# Nearest to has: had, have, is, was, antecedents, having, symphonic, does,
# Nearest to new: stricture, manichaeism, toppling, alec, cartoon, agp, auxiliaries, tripod,
# Average loss at step 72000: 3.377276
# Average loss at step 74000: 3.346422
# Average loss at step 76000: 3.311182
# Average loss at step 78000: 3.351969
# Average loss at step 80000: 3.376758
# Nearest to world: u, ipv, whodunit, emmer, pianists, vietnam, nonnegative, sun,
# Nearest to these: several, many, those, both, such, various, some, different,
# Nearest to be: been, have, being, rafik, jaguars, produce, become, were,
# Nearest to an: dial, promptly, lessen, complemented, cleavage, prohibiting, untrustworthy, niches,
# Nearest to would: could, will, can, should, may, might, must, did,
# Nearest to many: some, several, these, various, numerous, most, both, those,
# Nearest to which: this, that, also, usually, typically, what, who, often,
# Nearest to and: or, including, but, while, although, nyc, however, cordell,
# Nearest to first: last, second, next, final, third, milestones, fourth, clicked,
# Nearest to their: its, his, her, our, fraught, your, both, these,
# Nearest to known: used, defined, regarded, described, called, possible, classified, considered,
# Nearest to two: three, six, four, five, seven, one, eight, zero,
# Nearest to six: seven, five, four, eight, three, nine, two, zero,
# Nearest to seven: six, eight, four, five, nine, three, zero, one,
# Nearest to has: had, have, is, was, having, antecedents, although, garland,
# Nearest to new: ethnography, tripod, shrublands, stricture, delia, repented, unrepentant, expires,
# Average loss at step 82000: 3.409715
# Average loss at step 84000: 3.416727
# Average loss at step 86000: 3.389833
# Average loss at step 88000: 3.350581
# Average loss at step 90000: 3.362203
# Nearest to world: emmer, whodunit, pianists, ipv, vietnam, masculism, redfern, eminently,
# Nearest to these: several, some, many, those, such, are, certain, their,
# Nearest to be: been, become, have, was, is, prove, being, produce,
# Nearest to an: promptly, lessen, dial, nahum, smoothing, another, mh, niches,
# Nearest to would: will, could, should, might, may, can, must, did,
# Nearest to many: some, several, various, these, numerous, most, all, those,
# Nearest to which: that, also, this, usually, what, who, often, typically,
# Nearest to and: or, but, including, while, however, although, disarmament, toward,
# Nearest to first: last, second, next, final, third, fourth, ruining, best,
# Nearest to their: its, his, her, our, your, the, whose, my,
# Nearest to known: used, defined, regarded, described, possible, such, interpreted, called,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to seven: eight, four, six, nine, five, three, zero, one,
# Nearest to has: had, have, is, was, having, garland, requires, since,
# Nearest to new: delia, tripod, expires, stewardship, stricture, colloids, cartoon, nils,
# Average loss at step 92000: 3.401044
# Average loss at step 94000: 3.256461
# Average loss at step 96000: 3.361546
# Average loss at step 98000: 3.240867
# Average loss at step 100000: 3.355603
# Nearest to world: ipv, emmer, whodunit, vietnam, u, civil, pianists, masculism,
# Nearest to these: several, some, many, those, various, different, their, such,
# Nearest to be: been, is, being, have, become, are, prove, jaguars,
# Nearest to an: another, lessen, promptly, smoothing, complemented, mw, penzance, niches,
# Nearest to would: could, will, should, might, can, may, must, did,
# Nearest to many: several, some, various, these, numerous, all, few, those,
# Nearest to which: that, this, also, usually, what, typically, these, who,
# Nearest to and: or, but, including, although, when, while, however, halide,
# Nearest to first: last, second, next, third, fourth, final, clicked, previous,
# Nearest to their: its, his, her, our, your, the, several, these,
# Nearest to known: defined, possible, used, such, interpreted, regarded, described, classified,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to seven: eight, six, four, nine, five, three, two, zero,
# Nearest to has: had, have, is, having, was, since, requires, symphonic,
# Nearest to new: tripod, expires, ethnography, colloids, uncodified, classic, stricture, different,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
